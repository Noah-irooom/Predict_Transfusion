# %%
import pandas as pd

df = pd.read_csv(r'C:/Users/user/Desktop/pivot_input_test.csv')
df
# Out:
#        ICUSTAY_ID  CAL_CHARTEVENT_TIME  ('CAL_TIME_AVG', 50801)  \
# 0          200131                    0                      NaN
# 1          200131                    1                      NaN
# 2          200131                    2                      NaN
# 3          200131                    3                      NaN
# 4          200131                    4                      NaN
# ...           ...                  ...                      ...
# 35709      299931                   19                      NaN
# 35710      299931                   20                      NaN
# 35711      299931                   21                      NaN
# 35712      299931                   22                      NaN
# 35713      299931                   23                      NaN
#
#        ('CAL_TIME_AVG', 50802)  ('CAL_TIME_AVG', 50803)  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# ...

# %%
import numpy as np
ls = np.array([0., 1., 0., 0.])
ls1 = np.array([0., 0., 1., 0.])

# %%
ls + ls1
# Out:
# array([0., 1., 1., 0.])

# %%
len(df.ICUSTAY_ID.unique())
# Out:
# 2000

# %%
(1058 + 1418) - 2000
# Out:
# 476

# %%
lab = pd.read_csv('./sungbin/8_29_LABEVENTS_age_90_commit.csv')

# %%
lab
# Out:
#         SUBJECT_ID  HADM_ID  ICUSTAY_ID GENDER  first_admit_age ETHNICITY  \
# 0              166   128219      271863      F               90     WHITE
# 1              166   128219      271863      F               90     WHITE
# 2              166   128219      271863      F               90     WHITE
# 3              166   128219      271863      F               90     WHITE
# 4              166   128219      271863      F               90     WHITE
# ...            ...      ...         ...    ...              ...       ...
# 275849       99985   176670      279638      M               54     WHITE
# 275850       99985   176670      279638      M               54     WHITE
# 275851       99985   176670      279638      M               54     WHITE
# 275852       99985   176670      279638      M               54     WHITE
# 275853       99985   176670      279638      M               54     WHITE
#
#        DIAGNOSIS  ITEMID  CAL_LAB_TIME  MEAN_VALUENUM
# ...

# %%
df.iloc[:,2].value_counts()
# Out:
# 0.866426    5
# 0.635379    5
# 0.935018    4
# 0.906137    4
# 0.862816    4
#            ..
# 0.718412    1
# 0.773466    1
# 0.586643    1
# 0.796029    1
# 0.610108    1
# Name: ('CAL_TIME_AVG', 50801), Length: 312, dtype: int64

# %%
df
# Out:
#        ICUSTAY_ID  CAL_CHARTEVENT_TIME  ('CAL_TIME_AVG', 50801)  \
# 0          200131                    0                      NaN
# 1          200131                    1                      NaN
# 2          200131                    2                      NaN
# 3          200131                    3                      NaN
# 4          200131                    4                      NaN
# ...           ...                  ...                      ...
# 35709      299931                   19                      NaN
# 35710      299931                   20                      NaN
# 35711      299931                   21                      NaN
# 35712      299931                   22                      NaN
# 35713      299931                   23                      NaN
#
#        ('CAL_TIME_AVG', 50802)  ('CAL_TIME_AVG', 50803)  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# ...

# %%
df.describe()
# Out:
#           ICUSTAY_ID  CAL_CHARTEVENT_TIME  ('CAL_TIME_AVG', 50801)  \
# count   35714.000000         35714.000000               476.000000
# mean   249302.034244            11.111077                 0.719855
# std     29328.309263             6.905214                 0.190948
# min    200131.000000             0.000000                 0.000000
# 25%    222580.000000             5.000000                 0.621841
# 50%    250140.000000            11.000000                 0.764140
# 75%    275597.000000            17.000000                 0.866426
# max    299931.000000            23.000000                 0.994585
#
#        ('CAL_TIME_AVG', 50802)  ('CAL_TIME_AVG', 50803)  \
# count              5584.000000               157.000000
# mean                  0.950639                 0.375035
# std                   0.012563                 0.141318
# min                   0.807225                 0.000000
# 25%                   0.944828                 0.304348
# ...

# %%
lab.ITEMID.value_counts()
# Out:
# 51221    6962
# 50971    6693
# 50983    6516
# 50902    6303
# 50912    6294
#          ...
# 51317       1
# 51155       1
# 51153       1
# 51061       1
# 51481       1
# Name: ITEMID, Length: 505, dtype: int64

# %%
table = pd.pivot_table(lab, values='MEAN_VALUENUM', index=['ICUSTAY_ID', 'CAL_LAB_TIME'],
                    columns=['ITEMID'])

# %%
table
# Out:
# ITEMID                   50801     50802  50803     50804  50805  50806  \
# ICUSTAY_ID CAL_LAB_TIME
# 200131     1               NaN       NaN    NaN       NaN    NaN    NaN
#            2               NaN       NaN    NaN       NaN    NaN    NaN
#            3               NaN  0.956322    NaN  0.456140    NaN    NaN
#            4               NaN       NaN    NaN       NaN    NaN    NaN
#            5               NaN  0.956322    NaN  0.473684    NaN    NaN
# ...                        ...       ...    ...       ...    ...    ...
# 299931     19              NaN       NaN    NaN       NaN    NaN    NaN
#            20              NaN       NaN    NaN       NaN    NaN    NaN
#            21              NaN       NaN    NaN       NaN    NaN    NaN
#            22              NaN       NaN    NaN       NaN    NaN    NaN
#            23              NaN       NaN    NaN       NaN    NaN    NaN
#
# ITEMID                   50808  50809     50810     50811  ...     51482  \
# ...

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 11902 entries, (200131, 1) to (299931, 23)
# Columns: 280 entries, 50801 to 51517
# dtypes: float64(280)
# memory usage: 25.5 MB

# %%
table.describe()
# Out:
# ITEMID       50801        50802       50803        50804      50805  \
# count   476.000000  5584.000000  157.000000  5585.000000  34.000000
# mean      0.719855     0.950639    0.375035     0.435738   0.250000
# std       0.190948     0.012563    0.141318     0.110489   0.222852
# min       0.000000     0.807225    0.000000     0.035088   0.000000
# 25%       0.621841     0.944828    0.304348     0.368421   0.142857
# 50%       0.764140     0.950575    0.369565     0.426901   0.142857
# 75%       0.866426     0.958238    0.434783     0.502924   0.285714
# max       0.994585     1.000000    1.000000     1.000000   1.000000
#
# ITEMID       50806        50808        50809       50810       50811  ...  \
# count   551.000000  2707.000000  1628.000000  680.000000  679.000000  ...
# mean      0.528754     0.394862     0.174651    0.474209    0.469590  ...
# std       0.125216     0.042311     0.079565    0.145282    0.145238  ...
# ...

# %%
table.notnull().sum()
# Out:
# ITEMID
# 50801     476
# 50802    5584
# 50803     157
# 50804    5585
# 50805      34
#          ...
# 51498    1765
# 51501      24
# 51514     358
# 51516     667
# 51517       2
# Length: 280, dtype: int64

# %%
table.notnull().sum().describe()
# Out:
# count     280.000000
# mean      841.232143
# std      1744.211138
# min         2.000000
# 25%        11.000000
# 50%        46.000000
# 75%       495.500000
# max      6962.000000
# dtype: float64

# %%
# table.notnull().sum().sort_values(ascending=False).index[:10]
table.notnull().sum().sort_values(ascending=False).index[:20]
# Out:
# Int64Index([51221, 50971, 50983, 50902, 50912, 51006, 50882, 50868, 50931,
#             51265, 51222, 51301, 50820, 51277, 51279, 51248, 51249, 51250,
#             50960, 50804],
#            dtype='int64', name='ITEMID')

# %%
# 상위 20개만 뽑아냄. - Hb 포함위해
ls = table.notnull().sum().sort_values(ascending=False).index[:20]
for_mer = pd.DataFrame(ls, columns=['ITEMID'])
lab_new = pd.merge(lab, for_mer, on='ITEMID', how='inner')
print(len(lab_new.ITEMID.unique()))
lab_new
# Out:
# 20
#         SUBJECT_ID  HADM_ID  ICUSTAY_ID GENDER  first_admit_age  \
# 0              166   128219      271863      F               90
# 1              275   129886      219649      M               82
# 2              275   129886      219649      M               82
# 3              275   129886      219649      M               82
# 4              275   129886      219649      M               82
# ...            ...      ...         ...    ...              ...
# 120170       99785   120655      267661      F               72
# 120171       99985   176670      279638      M               54
# 120172       99985   176670      279638      M               54
# 120173       99985   176670      279638      M               54
# 120174       99985   176670      279638      M               54
#
#                ETHNICITY                          DIAGNOSIS  ITEMID  \
# 0                  WHITE                             SEPSIS   50804
# ...

# %%
lab_new.to_csv('./sungbin/9_14_LABEVENTS_ITEMID_20_new_ver.csv', index=False)

# %%
lab.first_admit_age = lab.apply(lambda row: 90 if row.first_admit_age >= 300 else row.first_admit_age, axis=1)
lab
# Out:
#         SUBJECT_ID  HADM_ID  ICUSTAY_ID GENDER  first_admit_age ETHNICITY  \
# 0              166   128219      271863      F               90     WHITE
# 1              166   128219      271863      F               90     WHITE
# 2              166   128219      271863      F               90     WHITE
# 3              166   128219      271863      F               90     WHITE
# 4              166   128219      271863      F               90     WHITE
# ...            ...      ...         ...    ...              ...       ...
# 275849       99985   176670      279638      M               54     WHITE
# 275850       99985   176670      279638      M               54     WHITE
# 275851       99985   176670      279638      M               54     WHITE
# 275852       99985   176670      279638      M               54     WHITE
# 275853       99985   176670      279638      M               54     WHITE
#
#        DIAGNOSIS  ITEMID  CAL_LAB_TIME  MEAN_VALUENUM
# ...

# %%
lab.to_csv('./sungbin/8_29_LABEVENTS_age_90_commit.csv', index=False)

# %%
ls = lab.ITEMID.value_counts()[:50].index

# %%
for_mer.head()
# Out:
#    ITEMID  label
# 0   51221      1
# 1   50971      1
# 2   50983      1
# 3   50902      1
# 4   50912      1

# %%
new = pd.merge(lab, for_mer, on='ITEMID', how='left')
new
# Out:
#         SUBJECT_ID  HADM_ID  ICUSTAY_ID GENDER  first_admit_age ETHNICITY  \
# 0              166   128219      271863      F               90     WHITE
# 1              166   128219      271863      F               90     WHITE
# 2              166   128219      271863      F               90     WHITE
# 3              166   128219      271863      F               90     WHITE
# 4              166   128219      271863      F               90     WHITE
# ...            ...      ...         ...    ...              ...       ...
# 275849       99985   176670      279638      M               54     WHITE
# 275850       99985   176670      279638      M               54     WHITE
# 275851       99985   176670      279638      M               54     WHITE
# 275852       99985   176670      279638      M               54     WHITE
# 275853       99985   176670      279638      M               54     WHITE
#
#        DIAGNOSIS  ITEMID  CAL_LAB_TIME  MEAN_VALUENUM  label
# ...

# %%
test = pd.DataFrame(ls, columns=['ITEMID'])
new_test = pd.merge(lab, test, on='ITEMID', how='inner')

# %%
new_test.to_csv('./sungbin/8_29_LABEVENTS_50_ITEMID.csv', index=False)

# %%
len(new_test.ITEMID.unique())
# Out:
# 50

# %%
import pandas as pd
df = pd.read_csv('./sungbin/8_29_LABEVENTS_50_ITEMID.csv')
df
# Out:
#         SUBJECT_ID  HADM_ID  ICUSTAY_ID GENDER  first_admit_age  \
# 0              166   128219      271863      F               90
# 1              275   129886      219649      M               82
# 2              275   129886      219649      M               82
# 3              275   129886      219649      M               82
# 4              275   129886      219649      M               82
# ...            ...      ...         ...    ...              ...
# 209765       99785   120655      267661      F               72
# 209766       99785   120655      267661      F               72
# 209767       99985   176670      279638      M               54
# 209768       99985   176670      279638      M               54
# 209769       99985   176670      279638      M               54
#
#                ETHNICITY                          DIAGNOSIS  ITEMID  \
# 0                  WHITE                             SEPSIS   50800
# ...

# %%
df
# Out:
#         SUBJECT_ID  HADM_ID  ICUSTAY_ID GENDER  first_admit_age  \
# 0              166   128219      271863      F               90
# 1              275   129886      219649      M               82
# 2              275   129886      219649      M               82
# 3              275   129886      219649      M               82
# 4              275   129886      219649      M               82
# ...            ...      ...         ...    ...              ...
# 209765       99785   120655      267661      F               72
# 209766       99785   120655      267661      F               72
# 209767       99985   176670      279638      M               54
# 209768       99985   176670      279638      M               54
# 209769       99985   176670      279638      M               54
#
#                ETHNICITY                          DIAGNOSIS  ITEMID  \
# 0                  WHITE                             SEPSIS   50800
# ...

# %% [markdown]
# # MV CV 대상군 통합 랩이벤트 상위 20개만 뽑기

# %%
import pandas as pd
lab = pd.read_csv('./sungbin/9_18_LABEVENTS_mean_valuenum.csv')
lab
# Out:
#          SUBJECT_ID  HADM_ID  ICUSTAY_ID  ITEMID  CAL_LAB_TIME  MEAN_VALUENUM
# 0                 4   185777      294638   50861          11.0       0.009323
# 1                 4   185777      294638   50861          13.0       0.007444
# 2                 4   185777      294638   50862          13.0       0.576271
# 3                 4   185777      294638   50867          11.0       0.016296
# 4                 4   185777      294638   50878          13.0       0.004479
# ...             ...      ...         ...     ...           ...            ...
# 2298368       99999   113369      246512   51250          17.0       0.670290
# 2298369       99999   113369      246512   51265          17.0       0.064993
# 2298370       99999   113369      246512   51277          17.0       0.397239
# 2298371       99999   113369      246512   51279          17.0       0.324444
# 2298372       99999   113369      246512   51301          17.0       0.028692
#
# [2298373 rows x 6 columns]

# %%
lab['ITEMID'].value_counts()
# Out:
# 51221    74102
# 50971    72113
# 50983    68637
# 50902    68263
# 50882    67535
#          ...
# 50869        1
# 51050        1
# 50846        1
# 50840        1
# 51225        1
# Name: ITEMID, Length: 439, dtype: int64

# %%
table = pd.pivot_table(lab, values='MEAN_VALUENUM', index=['ICUSTAY_ID', 'CAL_LAB_TIME'],
                    columns=['ITEMID'])

# %%
table
# Out:
# ITEMID                   50801     50802  50803     50804  50805     50806  \
# ICUSTAY_ID CAL_LAB_TIME
# 200006     3.0             NaN       NaN    NaN       NaN    NaN       NaN
#            16.0            NaN       NaN    NaN       NaN    NaN       NaN
#            18.0            NaN       NaN    NaN       NaN    NaN       NaN
#            20.0            NaN       NaN    NaN       NaN    NaN       NaN
#            21.0            NaN       NaN    NaN       NaN    NaN       NaN
# ...                        ...       ...    ...       ...    ...       ...
# 299979     13.0            NaN  0.917226    NaN  0.323529    NaN  0.754098
#            14.0            NaN       NaN    NaN       NaN    NaN       NaN
#            18.0            NaN       NaN    NaN       NaN    NaN       NaN
# 299984     2.0             NaN       NaN    NaN       NaN    NaN       NaN
#            3.0             NaN       NaN    NaN       NaN    NaN       NaN
#
# ...

# %%
table.describe()
# Out:
# ITEMID        50801         50802        50803         50804       50805  \
# count   2857.000000  44079.000000  1253.000000  44075.000000  248.000000
# mean       0.677511      0.923852     0.359286      0.379022    0.147807
# std        0.139873      0.008215     0.086238      0.064551    0.101064
# min        0.335172      0.903803     0.166667      0.235294    0.000000
# 25%        0.582069      0.919463     0.296296      0.338235    0.087500
# 50%        0.703448      0.923937     0.351852      0.375000    0.125000
# 75%        0.794483      0.928412     0.425926      0.419118    0.250000
# max        1.000000      0.944072     0.555556      0.544118    0.375000
#
# ITEMID        50806         50808         50809         50810         50811  \
# count   6140.000000  23918.000000  19655.000000  10144.000000  10052.000000
# mean       0.703536      0.009728      0.074721      0.506313      0.505935
# std        0.037963      0.000745      0.018193      0.086325      0.084320
# ...

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 135991 entries, (200006, 3.0) to (299984, 3.0)
# Columns: 393 entries, 50801 to 51529
# dtypes: float64(393)
# memory usage: 408.3 MB

# %%
ls = table.notnull().sum().sort_values(ascending=False).index[:20]
for_mer = pd.DataFrame(ls, columns=['ITEMID'])
lab_new = pd.merge(lab, for_mer, on='ITEMID', how='inner')
print(len(lab_new.ITEMID.unique()))
lab_new
# Out:
# 20
#          SUBJECT_ID  HADM_ID  ICUSTAY_ID  ITEMID  CAL_LAB_TIME  MEAN_VALUENUM
# 0                 4   185777      294638   50912          11.0       0.001114
# 1                 4   185777      294638   50912          13.0       0.001114
# 2                13   143045      263738   50912           1.0       0.000743
# 3                13   143045      263738   50912           3.0       0.000619
# 4                13   143045      263738   50912           6.0       0.000681
# ...             ...      ...         ...     ...           ...            ...
# 1270394       99985   176670      279638   51301           6.0       0.027595
# 1270395       99985   176670      279638   51301          12.0       0.040765
# 1270396       99985   176670      279638   51301          22.0       0.060207
# 1270397       99985   176670      279638   51301          23.0       0.040295
# 1270398       99999   113369      246512   51301          17.0       0.028692
#
# [1270399 rows x 6 columns]

# %%
# lab_new.to_csv('./sungbin/10_05_LAB_20ITEMS.csv',index=False)

# %%
table.notnull()
# Out:
# ITEMID                   50801  50802  50803  50804  50805  50806  50808  \
# ICUSTAY_ID CAL_LAB_TIME
# 200006     3.0           False  False  False  False  False  False  False
#            16.0          False  False  False  False  False  False  False
#            18.0          False  False  False  False  False  False  False
#            20.0          False  False  False  False  False  False  False
#            21.0          False  False  False  False  False  False  False
# ...                        ...    ...    ...    ...    ...    ...    ...
# 299979     13.0          False   True  False   True  False   True   True
#            14.0          False  False  False  False  False  False  False
#            18.0          False  False  False  False  False  False  False
# 299984     2.0           False  False  False  False  False  False  False
#            3.0           False  False  False  False  False  False  False
#
# ...

# %%
table.notnull().sum().sort_values(ascending=False)
# Out:
# ITEMID
# 51221    74102
# 50971    72113
# 50983    68637
# 50902    68263
# 50882    67535
#          ...
# 51165        2
# 51166        2
# 50830        1
# 51058        1
# 51346        1
# Length: 393, dtype: int64

# %%
table.notnull().sum().sort_values(ascending=False).index[:20]
